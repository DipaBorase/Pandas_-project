# %%
import pandas as pd

# %%
customers=pd.read_csv("/content/customers.csv",
                      header= None,
                      names=['custno',
                             'firstname',
                             'lastname',
                             'gender',
                             'age',
                             'profession',
                             'contactNo',
                             'emailId',
                             'city',
                             'state',
                             'isActive',
                             'createdDate',
                             'UpdatedDate'])
customers
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         1    Leslie      Bass      F   27          B      37307
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         5    Martha     Combs      F   49          B      83947
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     966     Myron     Blake      M   46          S      82675
# 998     967      Tina   Sargent      F   60          B      32097
# 999     968     Paula     Young      M   32          S      23603
#
#                           emailId        city        state isActive  \
# 0          endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
products=pd.read_csv("/content/products.csv",
                     header=None,
                     names=['productno',
                            'productName',
                            'Description',
                            'isActive',
                            'createdDate',
                            'UpdatedDate'])
products
# Out:
#      productno  productName Description isActive          createdDate  \
# 0            1     Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1            2     Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2            3     Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3            4     Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4            5     Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# ..         ...          ...         ...      ...                  ...
# 995        996   Product996  acvxzpvhyu        Y  2017-09-09 07:49:14
# 996        997   Product997  eguyggimfm        Y  2017-09-14 12:13:29
# 997        998   Product998  hagbslxugf        Y  2017-04-20 06:25:03
# 998        999   Product999  iuoraxdrlf        Y  2017-03-06 05:00:08
# 999       1000  Product1000  ewgaacrkht        N  2017-07-13 02:52:44
#
#              UpdatedDate
# 0    2017-10-18 12:12:38
# 1    2017-10-18 12:12:38
# 2    2017-10-18 12:12:38
# ...

# %%
transactions=pd.read_csv("/content/transactions.csv",header=None,names=['txnno','txndate','custno','amount','productno','spendby'])
transactions
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 0        1  2017-10-18 12:31:45     923    2559        376    Card
# 1        2  2017-10-18 12:31:45     219    1706        151    Card
# 2        3  2017-10-18 12:31:45     927    3462        707    Cash
# 3        4  2017-10-18 12:31:45     806     865        539    Card
# 4        5  2017-10-18 12:31:45     958    2494         25    Card
# ..     ...                  ...     ...     ...        ...     ...
# 995    996  2017-10-18 12:31:46     653    2872        155    Cash
# 996    997  2017-10-18 12:31:46     849     815        386    Card
# 997    998  2017-10-18 12:31:46     939    3932        529    Card
# 998    999  2017-10-18 12:31:46     547    3021        774    Cash
# 999   1000  2017-10-18 12:31:46     204    2314        828    Card
#
# [1000 rows x 6 columns]

# %% [markdown]
# Top Five Records

# %%
print(" Customers first five records")
customers.head()
# Out:
#  Customers first five records
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive      createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  9/21/2017 12:38
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y   5/22/2017 5:29
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y   9/3/2017 12:11
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y   2/16/2017 4:05
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y   5/15/2017 7:34
#
#         UpdatedDate
# 0  10/18/2017 12:12
# 1  10/18/2017 12:12
# 2  10/18/2017 12:12
# 3  10/18/2017 12:12
# ...

# %%
print(" Transactions first five records")
transactions.head()
# Out:
#  Transactions first five records
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %%
print("Products first five records")
products.head()
# Out:
# Products first five records
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %% [markdown]
# Customers purchased more than 3 products

# %%
df=transactions.groupby('custno').count()
df1=df.sort_values(by='amount',ascending=False)
top_3=df1[df1>3].dropna()
pd.merge(customers,top_3,on='custno')
# Out:
#     custno  firstname  lastname gender  age profession  contactNo  \
# 0        4     Alexis    Battle      M   27          S      71701
# 1       86     Bonnie    McCall      M   37          S      70907
# 2      167      Alice     Blake      F   58          B      22324
# 3      187       Alan   Anthony      F   50          B      40487
# 4      237       Dawn      West      F   26          B      75618
# 5      241    Derrick   Pearson      F   33          B      74138
# 6      321    Crystal        Le      F   64          B      37857
# 7      326      Heidi   Stanley      M   29          S      78822
# 8      331    Cynthia  Harrison      F   49          B      53439
# 9      356   Mitchell     Mason      M   37          S      45064
# 10     391      Keith    Church      F   19          B      26859
# 11     537       Jake      Bush      F   23          B      80535
# 12     558       Lois      Todd      M   58          S      39051
# ...

# %% [markdown]
# top 5 most demanded products

# %%
df=transactions.groupby('custno').count()
df1=df.sort_values(by='amount',ascending=False).head()
pd.merge(products,df1,on='productno')
# Out:
#    productno productName Description isActive          createdDate  \
# 0          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 1          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 2          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 3          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate  txnno  txndate  amount  spendby
# 0  2017-10-18 12:12:38      4        4       4        4
# 1  2017-10-18 12:12:38      4        4       4        4
# 2  2017-10-18 12:12:38      4        4       4        4
# 3  2017-10-18 12:12:38      5        5       5        5
# 4  2017-10-18 12:12:38      5        5       5        5

# %% [markdown]
# top 5 transactions amount

# %%
transactions.sort_values(by='amount',ascending=False).head()
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 556    557  2017-10-18 12:31:46     670    4996        509    Card
# 305    306  2017-10-18 12:31:46     448    4992        427    Cash
# 574    575  2017-10-18 12:31:46     305    4981        549    Card
# 531    532  2017-10-18 12:31:46     230    4980        658    Card
# 232    233  2017-10-18 12:31:45     287    4966        685    Card

# %% [markdown]
# distinct professions

# %%
customers['profession'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %% [markdown]
# highest age

# %%
customers.sort_values(by='age',ascending=False).head(1)
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 500     501    Morgan  Donaldson      F   64          B      52553
#
#                 emailId      city   state isActive     createdDate  \
# 500  ggordon8@yah00.biz  Elberton  Codell        Y  8/15/2017 1:08
#
#           UpdatedDate
# 500  10/18/2017 12:12

# %% [markdown]
# custno, gender, age, profession, contactno, productno, productName,
# txndate, spendby, amount from CSV_s1 for custno = 923

# %%
A=customers[customers['custno']==923]
df=pd.merge(A,transactions,on='custno')
df1=pd.merge(df,products,on='productno')
df1[['custno', 'gender', 'age', 'profession', 'productno', 'contactNo','productName', 'txndate', 'spendby', 'amount']]
# Out:
#    custno gender  age profession  productno  contactNo productName  \
# 0     923      F   46          B        376      25436  Product376
# 1     923      F   46          B        113      25436  Product113
# 2     923      F   46          B        644      25436  Product644
#
#                txndate spendby  amount
# 0  2017-10-18 12:31:45    Card    2559
# 1  2017-10-18 12:31:46    Card    2303
# 2  2017-10-18 12:31:46    Cash    4553

# %% [markdown]
# Text file

# %%
customer1=pd.read_csv("/content/customers.txt",delimiter="|",header= None,
                      names=['custno',
                             'firstname',
                             'lastname',
                             'gender',
                             'age',
                             'profession',
                             'contactNo',
                             'emailId',
                             'city',
                             'state',
                             'isActive',
                             'createdDate',
                             'UpdatedDate'])
customer1
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 0         1    Leslie       Bass      F   27          B      37307
# 1         2      Judy      Burks      M   53          S      84759
# 2         3    Marsha      Doyle      F   48          B      80932
# 3         4    Alexis     Battle      M   27          S      71701
# 4         5    Martha      Combs      F   49          B      83947
# ..      ...       ...        ...    ...  ...        ...        ...
# 995     996   Roxanne  Velazquez      M   37          S      57463
# 996     997   Kristen       Wall      F   20          B      62662
# 997     998     Terry  Blackwell      M   28          S      49457
# 998     999     Betty       Leon      F   23          B      69268
# 999    1000    Connie    Andrews      M   47          S      78445
#
#                          emailId                 city      state isActive  \
# 0         endslost@everyma1l.org               Gibson   Dellwood        Y
# ...

# %%
product1=pd.read_csv("/content/products.txt",delimiter="|",header=None,
                     names=['productno',
                            'productName',
                            'Description',
                            'isActive',
                            'createdDate',
                            'UpdatedDate'])
product1
# Out:
#      productno  productName Description isActive          createdDate  \
# 0            1     Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1            2     Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2            3     Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3            4     Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4            5     Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# ..         ...          ...         ...      ...                  ...
# 995        996   Product996  acvxzpvhyu        Y  2017-09-09 07:49:14
# 996        997   Product997  eguyggimfm        Y  2017-09-14 12:13:29
# 997        998   Product998  hagbslxugf        Y  2017-04-20 06:25:03
# 998        999   Product999  iuoraxdrlf        Y  2017-03-06 05:00:08
# 999       1000  Product1000  ewgaacrkht        N  2017-07-13 02:52:44
#
#              UpdatedDate
# 0    2017-10-18 12:12:38
# 1    2017-10-18 12:12:38
# 2    2017-10-18 12:12:38
# ...

# %%
transaction1=pd.read_csv("/content/transactions.txt",delimiter='|',header=None,names=['txnno','txndate','custno','amount','productno','spendby']
                     )
transaction1
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 0        1  2017-10-18 12:31:45     923    2559        376    Card
# 1        2  2017-10-18 12:31:45     219    1706        151    Card
# 2        3  2017-10-18 12:31:45     927    3462        707    Cash
# 3        4  2017-10-18 12:31:45     806     865        539    Card
# 4        5  2017-10-18 12:31:45     958    2494         25    Card
# ..     ...                  ...     ...     ...        ...     ...
# 995    996  2017-10-18 12:31:46     653    2872        155    Cash
# 996    997  2017-10-18 12:31:46     849     815        386    Card
# 997    998  2017-10-18 12:31:46     939    3932        529    Card
# 998    999  2017-10-18 12:31:46     547    3021        774    Cash
# 999   1000  2017-10-18 12:31:46     204    2314        828    Card
#
# [1000 rows x 6 columns]

# %% [markdown]
# Top Five Records

# %%
print(" Customers first five records")
customer1.head()
# Out:
#  Customers first five records
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# ...

# %%
print("products first five records")
product1.head()
# Out:
# products first five records
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
print(" Transactions first five records")
transaction1.head()
# Out:
#  Transactions first five records
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %% [markdown]
# Customers purchased more than 3 products

# %%
df=transaction1.groupby('custno').count()
df1=df.sort_values(by='amount',ascending=False)
top_3=df1[df1>3].dropna()
pd.merge(customer1,top_3,on='custno')
# Out:
#     custno  firstname  lastname gender  age profession  contactNo  \
# 0        4     Alexis    Battle      M   27          S      71701
# 1       86     Bonnie    McCall      M   37          S      70907
# 2      167      Alice     Blake      F   58          B      22324
# 3      187       Alan   Anthony      F   50          B      40487
# 4      237       Dawn      West      F   26          B      75618
# 5      241    Derrick   Pearson      F   33          B      74138
# 6      321    Crystal        Le      F   64          B      37857
# 7      326      Heidi   Stanley      M   29          S      78822
# 8      331    Cynthia  Harrison      F   49          B      53439
# 9      356   Mitchell     Mason      M   37          S      45064
# 10     391      Keith    Church      F   19          B      26859
# 11     537       Jake      Bush      F   23          B      80535
# 12     558       Lois      Todd      M   58          S      39051
# ...

# %% [markdown]
# top 5 most demanded products

# %%
transaction1.sort_values(by='amount',ascending=False).head()
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 556    557  2017-10-18 12:31:46     670    4996        509    Card
# 305    306  2017-10-18 12:31:46     448    4992        427    Cash
# 574    575  2017-10-18 12:31:46     305    4981        549    Card
# 531    532  2017-10-18 12:31:46     230    4980        658    Card
# 232    233  2017-10-18 12:31:45     287    4966        685    Card

# %% [markdown]
# distinct professions

# %%
customer1['profession'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %% [markdown]
# highest age

# %%
customer1.sort_values(by='age',ascending=False).head(1)
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 500     501    Morgan  Donaldson      F   64          B      52553
#
#                 emailId      city   state isActive          createdDate  \
# 500  ggordon8@yah00.biz  Elberton  Codell        Y  2017-08-15 01:08:02
#
#              UpdatedDate
# 500  2017-10-18 12:12:29

# %% [markdown]
# custno, gender, age, profession, contactno, productno, productName, txndate, spendby, amount from CSV_s1 for custno = 923

# %%
A=customer1[customer1['custno']==923]
df=pd.merge(A,transaction1,on='custno')
df1=pd.merge(df,product1,on='productno')
df1[['custno', 'gender', 'age', 'profession', 'productno', 'contactNo','productName', 'txndate', 'spendby', 'amount']]
# Out:
#    custno gender  age profession  productno  contactNo productName  \
# 0     923      F   46          B        376      25436  Product376
# 1     923      F   46          B        113      25436  Product113
# 2     923      F   46          B        644      25436  Product644
#
#                txndate spendby  amount
# 0  2017-10-18 12:31:45    Card    2559
# 1  2017-10-18 12:31:46    Card    2303
# 2  2017-10-18 12:31:46    Cash    4553

# %% [markdown]
# xml file

# %%
customer2=pd.read_xml('/content/customers.xml',
                      names=['custno',
                             'firstname',
                             'lastname',
                             'gender',
                             'age',
                             'profession',
                             'contactNo',
                             'emailId',
                             'city',
                             'state',
                             'isActive',
                             'createdDate',
                             'UpdatedDate'])
customer2
# Out:
#     custno firstname  lastname  gender  age          profession  \
# 0        1    Teegan   Hubbard       2   33     Human Resources
# 1        2    Deacon    Briggs       2   54  Customer Relations
# 2        3   Mallory   Shelton       1   57  Customer Relations
# 3        4     Quinn  Clements       2   43     Media Relations
# 4        5    Arthur     Hurst       2   41        Tech Support
# ..     ...       ...       ...     ...  ...                 ...
# 95      96   Harriet    Moreno       1   33    Legal Department
# 96      97      Nell    Sparks       1   63    Asset Management
# 97      98    Ashely      Lynn       1   30    Customer Service
# 98      99     Emily  Williams       2   30            Finances
# 99     100    Tashya    Dudley       1   31  Customer Relations
#
#         contactNo                                       emailId  \
# 0   1681121691699                     nibh.Quisque@placerat.com
# 1   1631082682999                    facilisis.eget@Nullaeu.com
# ...

# %%
product2=pd.read_xml("/content/products.xml",
                     names=['productno',
                            'productName',
                            'Description',
                            'isActive',
                            'createdDate',
                            'UpdatedDate'])
product2
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1         101           Honda       eight         1  2017-04-10  2017-11-11
# 2         102             GMC       three         2  2017-02-09  2017-11-17
# 3         103           Lexus       eight         2  2017-06-01  2017-11-04
# 4         104           Smart        five         2  2017-08-10  2017-11-16
# ..        ...             ...         ...       ...         ...         ...
# 95        195           Honda        four         2  2016-11-09  2017-11-19
# 96        196     Tata Motors       three         2  2016-11-17  2017-11-03
# 97        197        Kenworth        nine         1  2017-09-21  2017-11-09
# 98        198           Skoda        nine         2  2017-04-14  2017-11-14
# 99        199             BMW         six         2  2017-06-23  2017-11-15
#
# [100 rows x 6 columns]

# %%
transaction2=pd.read_xml("/content/transactions.xml",
                         names=['txnno',
                                'txndate',
                                'custno',
                                'amount',
                                'productno',
                                'spendby'])
transaction2
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-09-16       6     576         73        1
# 1       2  2018-02-11      96    1038         40        2
# 2       3  2017-06-13      17     673          2        1
# 3       4  2017-07-25      89    1284        100        2
# 4       5  2017-06-15       9    1685         56        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2018-11-10      59    1388         26        2
# 96     97  2017-09-13      57    1261         36        2
# 97     98  2017-10-29       7      93         60        1
# 98     99  2017-09-30       4     643         38        1
# 99    100  2017-10-12      77    1902         54        2
#
# [100 rows x 6 columns]

# %% [markdown]
# Top Five Records

# %%
print(" Customers first five records")
customer2.head()
# Out:
#  Customers first five records
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
# ...

# %%
print("Products first five records")
product2.head()
# Out:
# Products first five records
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
print("transactions first five records")
transaction2.head()
# Out:
# transactions first five records
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2

# %% [markdown]
# Customers purchased more than 3 products

# %%
df=transaction2.groupby('custno').count()
df1=df.sort_values(by='amount',ascending=False)
top_3=df1[df1>3].dropna()
pd.merge(customer2,top_3, on='custno')

print('Nobody purchase more than 3 products')
# Out:
# Nobody purchase more than 3 products

# %% [markdown]
# top 5 most demanded products

# %%
transaction2.sort_values(by='amount',ascending=False).head()
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 28     29  2018-09-29       1    1928         80        2
# 51     52  2018-05-05      14    1923         86        2
# 99    100  2017-10-12      77    1902         54        2
# 69     70  2018-07-26      18    1880          5        1
# 35     36  2018-08-05      19    1867         53        1

# %% [markdown]
# distinct professions

# %%
customer2['profession'].unique()
# Out:
# array(['Human Resources', 'Customer Relations', 'Media Relations',
#        'Tech Support', 'Advertising', 'Asset Management',
#        'Legal Department', 'Accounting', 'Finances',
#        'Research and Development', 'Sales and Marketing', 'Payroll',
#        'Quality Assurance', 'Customer Service', 'Public Relations'],
#       dtype=object)

# %% [markdown]
# highest age

# %%
customer2.sort_values(by='age',ascending=False).head(1)
# Out:
#     custno firstname  lastname  gender  age        profession      contactNo  \
# 32      33    Colton  Atkinson       1   65  Asset Management  1648031707899
#
#                             emailId       city state  isActive createdDate  \
# 32  elementum.dui.quis@sagittis.edu  Viesville    HE         2  2016-12-12
#
#    UpdatedDate
# 32  2018-09-12

# %% [markdown]
# custno, gender, age, profession, contactno, productno, productName, txndate, spendby, amount from CSV_s1 for custno = 923

# %%
A= customer2[customer2['custno']== 923]
df=pd.merge(A,transaction2,on='custno')
df1=pd.merge(df,product2,on='productno')
df1[['custno', 'gender', 'age', 'profession', 'productno', 'contactNo','productName', 'txndate', 'spendby', 'amount']]
print("no custno = 923 exists in customer2")
# Out:
# no custno = 923 exists in customer2

# %% [markdown]
# json file

# %%
product3= pd.read_json("/content/products.json",orient="values")
product3
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1         101          Toyota         six         2  2017-10-03  2017-11-13
# 2         102  General Motors         two         1  2017-09-18  2017-11-03
# 3         103         Renault       eight         2  2017-10-05  2017-11-13
# 4         104        Kenworth       three         1  2017-05-03  2017-11-04
# ..        ...             ...         ...       ...         ...         ...
# 95        195             BMW        nine         2  2017-05-06  2017-11-18
# 96        196            Fiat       seven         2  2016-11-13  2017-11-17
# 97        197         Renault        five         1  2017-09-23  2017-11-16
# 98        198      Kia Motors       seven         2  2017-05-27  2017-11-02
# 99        199      RAM Trucks       eight         2  2017-04-05  2017-11-20
#
# [100 rows x 6 columns]

# %%
import pandas as pd
customer3=pd.read_json("/content/customers.json",orient='values')
customer3
# Out:
#     custno  firstname    lastname  gender  age          profession  \
# 0        1        Dai       Noble       2   53     Human Resources
# 1        2        Kay        Wise       2   26    Public Relations
# 2        3       Amir        Pace       1   43  Customer Relations
# 3        4  Sebastian       Lopez       2   32  Customer Relations
# 4        5      Brian      Maddox       1   40   Quality Assurance
# ..     ...        ...         ...     ...  ...                 ...
# 95      96     Tanner     Webster       1   29          Accounting
# 96      97    Tatiana       Gates       2   54         Advertising
# 97      98     Baxter  Valenzuela       1   43    Asset Management
# 98      99   Chadwick     Mcclure       2   42             Payroll
# 99     100       Tate       Booth       2   53         Advertising
#
#         contactNo                               emailId                 city  \
# 0   1644101928099          eu.lacus.Quisque@loremac.com               Berlin
# ...

# %%
transaction3= pd.read_json("/content/transactions.json",orient="values")
transaction3
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-07-31      71     181         19        2
# 1       2  2017-04-02      44     401         48        2
# 2       3  2018-01-31      45    1808         44        2
# 3       4  2018-04-02      62      65         22        2
# 4       5  2017-08-17      88    1149         74        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2017-02-14      81     124         29        1
# 96     97  2017-11-16       2     672         78        1
# 97     98  2018-08-14      43     538         61        1
# 98     99  2017-05-06      74    1856         95        2
# 99    100  2017-08-28      85     273         99        2
#
# [100 rows x 6 columns]

# %% [markdown]
# Top Five Records

# %%
print("Customers first five records")
customer3.head()
# Out:
# Customers first five records
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# ...

# %%
print("Products first five records")
product3.head()
# Out:
# Products first five records
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
print("transactions first five records")
transaction3.head()
# Out:
# transactions first five records
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %% [markdown]
# Customers purchased more than 3 products

# %%
df=transaction3.groupby('custno').count()
df1=df.sort_values(by='amount',ascending=False)
top_3=df1[df1>3].dropna()
pd.merge(customer3,top_3,on='custno')
# Out:
#    custno firstname lastname  gender  age                profession  \
# 0      34   Gregory  Stanton       2   29  Research and Development
# 1      36    Xandra     Holt       2   41                  Finances
# 2      88    Robert     Luna       1   56  Research and Development
#
#        contactNo                                 emailId       city    state  \
# 0  1679070209599                  consectetuer@Lorem.edu   Shipshaw       QC
# 1  1668031049999  montes.nascetur@laoreetposuereenim.edu    Rutland  Vermont
# 2  1681011904499                        primis@ipsum.com  Baracaldo       PV
#
#    isActive createdDate UpdatedDate  txnno  txndate  amount  productno  \
# 0         1  2017-05-29  2017-08-09    6.0      6.0     6.0        6.0
# 1         1  2017-04-14  2017-12-22    4.0      4.0     4.0        4.0
# 2         2  2017-04-10  2018-02-26    4.0      4.0     4.0        4.0
#
#    spendby
# 0      6.0
# 1      4.0
# 2      4.0

# %% [markdown]
# top 5 most demanded products

# %%
transaction3.sort_values(by='amount',ascending=False).head()
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 67     68  2018-07-16      34    1955         26        2
# 20     21  2017-11-04      57    1927         91        1
# 86     87  2018-01-25      56    1901         89        1
# 24     25  2018-08-02      61    1870         65        1
# 82     83  2018-10-25      40    1869         76        1

# %% [markdown]
# distinct professions

# %%
customer3['profession'].unique()
# Out:
# array(['Human Resources', 'Public Relations', 'Customer Relations',
#        'Quality Assurance', 'Payroll', 'Accounting', 'Advertising',
#        'Sales and Marketing', 'Tech Support', 'Asset Management',
#        'Research and Development', 'Customer Service', 'Media Relations',
#        'Finances', 'Legal Department'], dtype=object)

# %% [markdown]
# highest age

# %%
customer3.sort_values(by='age',ascending=False).head(1)
# Out:
#     custno firstname lastname  gender  age        profession      contactNo  \
# 72      73   Jameson   Barber       2   65  Asset Management  1659101735499
#
#                                 emailId    city   state  isActive createdDate  \
# 72  ac.eleifend.vitae@dictumProin.co.uk  Ankara  Ankara         1  2017-05-23
#
#    UpdatedDate
# 72  2018-03-22

# %% [markdown]
# custno, gender, age, profession, contactno, productno, productName, txndate, spendby, amount from CSV_s1 for custno = 923

# %%
A=customer3[customer3['custno']==923]
df=pd.merge(A,transaction3,on='custno')
df1=pd.merge(df,product3,on='productno')
df1[['custno', 'gender', 'age', 'profession', 'productno', 'contactNo','productName', 'txndate', 'spendby', 'amount']]
print("No exists custno=923 in customer3")
# Out:
# No exists custno=923 in customer3
